# %% [markdown]
# # Reading data from excel file

# %%
import pandas as pd

# %%
df = pd.read_excel("../dataset/Superstore Sales.xls",sheet_name=[0,1])
# df.head() #first five rows to print tail to print last five
df

# %%
df = pd.read_excel("../dataset/Superstore Sales.xls",sheet_name=["Orders","Returns","Users"])

Orders = df['Orders']
Returns = df['Returns']
Users = df['Users']

print(Orders)
print(Returns)
print(Users)

# %% [markdown]
# # Writing/Converting

# %%
wine_df = pd.read_excel('../dataset/testsheet.xlsx',sheet_name=0)
wine_df[:10]

wine_df.to_csv("../dataset/wine_quality.csv")

# %%
store_df = pd.read_excel("../dataset/Superstore Sales.xls",sheet_name=0)
store_df.to_csv("../dataset/superstore.csv")

# %% [markdown]
# # Date : 30/08/2023 -> Reading and writing from sql database

# %%
import pymysql
import pandas as pd

# %%
connect_db = pymysql.connect(
    host="127.0.0.1",
    user="root",
    passwd=""
)

myCursor = connect_db.cursor()

sql_query = "CREATE DATABASE mydb"

myCursor.execute(sql_query)

connect_db.close()

# %%
connect_db = pymysql.connect(
    host="127.0.0.1",
    user="root",
    passwd="",
    database="mydb"
)

df = pd.read_csv("../dataset/superstore.csv")

df.to_sql("../dataset/Supermarket",con=connect_db,if_exists='replace',index=False)
connect_db.close()

# %%
import sqlite3

con = sqlite3.connect("../dataset/mydb.db")
df = pd.read_csv("../dataset/superstore.csv")
myCursor = con.cursor()
df.to_sql("../dataset/Supermarket",con=con,if_exists='append',index=False)

# %%
import pymysql
connect_db = pymysql.connect(
    host="127.0.0.1",
    user="root",
    passwd="",
    database="mydb"
)


df = pd.read_csv("../dataset/superstore.csv")

df.to_sql("../dataset/Supermarket",con=connect_db,if_exists='replace')
connect_db.close()

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from sqlalchemy.exc import SQLAlchemyError

# Read CSV into DataFrame
csv_file_path = 'superstore.csv'
df = pd.read_csv(csv_file_path)

# Replace these with your MySQL credentials and database details
db_username = 'root'
db_password = ''
db_host = '127.0.0.1'
db_port = '3306'
db_name = 'mydb'

# Create a connection using pymysql
connection = pymysql.connect(
    host=db_host,
    user=db_username,
    password=db_password,
    db=db_name,
    cursorclass=pymysql.cursors.DictCursor
)

# Create an SQLAlchemy engine
engine = create_engine(f'mysql+pymysql://{db_username}:{db_password}@{db_host}/{db_name}')

try:
    with connection.cursor() as cursor:
        # Start a transaction
        connection.begin()

        # Store DataFrame in MySQL
        table_name = 'supermarket'
        df.to_sql(table_name, con=engine, if_exists='replace', index=False)

        # Commit the transaction
        connection.commit()

except SQLAlchemyError as e:
    print("An error occurred:", str(e))
    connection.rollback()  # Rollback the transaction

finally:
    connection.close()
    engine.dispose()

# %%
connect_db = pymysql.connect(
    host="127.0.0.1",
    user="root",
    passwd="",
    database="mydb"
)

mycursor = connect_db.cursor()


sql_query = """
INSERT INTO employee (id, name, age, gender, location)
VALUES
    (1, 'John Doe', 30, 'Male', 'New York'),
    (2, 'Jane Smith', 28, 'Female', 'Los Angeles'),
    (3, 'Michael Johnson', 35, 'Male', 'Chicago');
"""
mycursor.execute(sql_query)
connect_db.commit()

connect_db.close()

# %% [markdown]
# # 01/09/2023 - Indexing Selecting and Assigning

# %%
import pandas as pd
reviews = pd.read_csv("../dataset/winemag-data-130k-v2.csv",index_col=0)
reviews

# %%
# reviews['country']
reviews.country

# %%
type(reviews.country)

# %%
reviews['country'][-5:]

# %%
reviews[['country','points','price']].head()

# %%
reviews.iloc[0]#iloc - integer locator

# %%
reviews.iloc[:5,0:3]#row,col

# %%
reviews.iloc[[0,10,20],0]

# %%
reviews.iloc[-5:]

# %%
reviews.loc[0:50,'country']#label indexing

# %%
reviews.loc[0:50,['country','price']]

# %%
reviews.set_index('country')

# %%
reviews.set_index('country',inplace=True)

# %%
reviews.loc['France']

# %%
reviews.reset_index(inplace=True)
reviews

# %%
reviews.country == 'France'

# %%
reviews.loc[reviews.country == 'Italy']

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points>=90)]

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points>=90)]

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points>=90)]

# %%
reviews.loc[reviews.country.isin(['Italy','France','Germany'])]

# %%
reviews.loc[reviews.price.isnull()]
reviews.loc[reviews.price.notnull()]

# %%
reviews['critic'] = 'everyone'
reviews

# %% [markdown]
# ## 05/09/2023 - Information provider

# %%
import pandas as pd
hrdata = pd.read_csv('../dataset/HRDataset_v14.csv')
hrdata

# %%
print("Rows : ",hrdata.shape[0],len(hrdata))
print("Columns : ",hrdata.shape[1],len(hrdata.columns))

# %%
hrdata.dtypes

# %%
hrdata.isnull().sum()
hrdata.isnull().sum().sum()

# %%
hrdata.drop_duplicates()

# %%
rows,cols = hrdata.shape
rows
cols

# %%
hrdata.isna()

# %%
hrdata.duplicated()

# %%
import pandas as pd
creditcard = pd.read_csv('../dataset/creditcard.csv')

# %%
creditcard.shape

# %%
creditcard.dtypes

# %%
creditcard.isnull().sum()

# %%
creditcard.duplicated().sum()

# %%
hrdata.info()

# %%
hrdata_num = hrdata.select_dtypes(include="number")
hrdata_num.info()

# %%
hrdata_obj = hrdata.select_dtypes(exclude="number")
hrdata_obj

# %%
hrdata_num.columns

# %%
hrdata_num[['Salary', 'Termd',  'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount', 'DaysLateLast30', 'Absences']].describe().round(1).T

# '''25% - Q1/Lower Quartile
#    50% - Median
#    75% - Q2/Upper Quartile'''
# describe is used to statistical analyse

# %%
hrdata_obj.describe().T

# %%
hrdata.describe(include="object").T

# %%
hrdata_obj['Position'].value_counts()

# %%
hrdata_obj['State'].value_counts()

#value_counts to count categorical
#counts to count number

# %%
hrdata['State'].nunique()

# %%
hrdata['Position'].unique()

# %% [markdown]
# ## 06/09/2023

# %%
import pandas as pd
reviews = pd.read_csv("../dataset/winemag-data-130k-v2.csv",index_col=0)

# %%
reviews.price.dtype

# %%
reviews.dtypes

# %%
reviews['points'] = reviews.points.astype('float16')
reviews.points.dtype

# %%
reviews_null= reviews[reviews.isnull()]
reviews_null

# %%
reviews_notnull = reviews[reviews.notnull()]
reviews_notnull

# %%
import pandas as pd
startups_miss = pd.read_excel('../dataset/new_50.xlsx')
startups_miss
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4         NaN        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36         NaN  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
startups_miss.isnull().sum()

# %%
startups_miss[startups_miss.State.isnull()]

# %%
startups_miss[~startups_miss.State.isnull()]

# %%
reviews.isnull().sum()

# %%
reviews[reviews.country.isnull()]

# %%
reviews.isnull().sum()
missing_reviews = reviews[(reviews.country.isnull() | reviews.designation.isnull())]
missing_reviews

# %%
notMissing_reviews = reviews[~(reviews.country.isnull() | reviews.designation.isnull())]
notMissing_reviews

# %%
startups_miss['State'] = startups_miss.State.fillna('Unknown')
startups_miss['R&D Spend'] = startups_miss['R&D Spend'].fillna('Unknown')
startups_miss['Profit'] = startups_miss.Profit.fillna('Unknown')
startups_miss

# %%
startups_miss = startups_miss.fillna("Unknown")
startups_miss

# %%
startups_miss.replace("Unknown",999)

# %%
startups_miss.Administration.replace(136897.80,0,inplace=True)
startups_miss

# %%
startups_miss.dropna()
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 13   91992.39       135495.07        252664.93  California  134307.35

# %%
import pandas as pd
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}
df = pd.DataFrame(data)

df.groupby(by="Company")['Sales'].mean()
# Out:
# Company
# FB      296.5
# GOOG    160.0
# MSFT    232.0
# Name: Sales, dtype: float64

# %%
import pandas as pd
startups = pd.read_csv('../dataset/50_Startups.csv')
startups
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
startups.groupby(by="State")['Profit'].mean()
# Out:
# State
# California    103905.175294
# Florida       118774.024375
# New York      113756.446471
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")['Profit'].sum()
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")['Profit'].median()
# Out:
# State
# California     97427.84
# Florida       109543.12
# New York      108552.04
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")['Profit'].min()
# Out:
# State
# California    14681.40
# Florida       49490.75
# New York      35673.41
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")['Profit'].max()
# Out:
# State
# California    191792.06
# Florida       191050.39
# New York      192261.83
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")['Profit'].std()
# Out:
# State
# California    44446.359357
# Florida       35605.470428
# New York      41140.258117
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")['Profit'].var()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].mean()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].sum()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].median()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].min()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].max()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].std()
# Out:
# State
# California    1.975479e+09
# Florida       1.267750e+09
# New York      1.692521e+09
# Name: Profit, dtype: float64

# %%
startups.groupby(by="State")[['Profit','Marketing Spend']].var()
# Out:
#                   Profit  Marketing Spend
# State
# California  1.975479e+09     1.342793e+10
# Florida     1.267750e+09     8.090766e+09
# New York    1.692521e+09     2.257251e+10

# %%
datacsv = pd.read_csv('data.csv')
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
datacsv.groupby(by=["Car","Model"])[['CO2','Volume','Weight']].mean().sort_values(ascending=False,by="CO2")
# Out:
#                          CO2  Volume  Weight
# Car        Model
# Mercedes   SLK         120.0  2500.0  1395.0
# Volvo      XC70        117.0  2000.0  1746.0
# Mercedes   E-Class     115.0  2100.0  1605.0
# Audi       A6          114.0  2000.0  1725.0
# BMW        5           114.0  2000.0  1705.0
# Volvo      V70         109.0  1600.0  1523.0
# Opel       Zafira      109.0  1600.0  1405.0
# BMW        216         108.0  1600.0  1390.0
# VW         Up!         105.0  1000.0   929.0
# Ford       Focus       105.0  2000.0  1328.0
# Mini       Cooper      105.0  1500.0  1140.0
# Audi       A4          104.0  2000.0  1490.0
# Ford       B-Max       104.0  1600.0  1235.0
# Skoda      Rapid       104.0  1600.0  1119.0
# Mazda      3           104.0  2200.0  1280.0
# Mercedes   CLA         102.0  1500.0  1465.0
# Suzuki     Swift       101.0  1300.0   990.0
# Mercedes   C-Class      99.0  2100.0  1365.0
# Opel       Insignia     99.0  2000.0  1428.0
# ...

# %%
datacsv.groupby(by=["Car","Model"])[['CO2','Volume','Weight']].aggregate(['mean','median']).sort_values(by="Model")
# Out:
#                          CO2         Volume          Weight
#                         mean median    mean  median    mean  median
# Car        Model
# BMW        1            99.0   99.0  1600.0  1600.0  1365.0  1365.0
#            216         108.0  108.0  1600.0  1600.0  1390.0  1390.0
# Mazda      3           104.0  104.0  2200.0  2200.0  1280.0  1280.0
# BMW        5           114.0  114.0  2000.0  2000.0  1705.0  1705.0
# Fiat       500          90.0   90.0   900.0   900.0   865.0   865.0
# Mercedes   A-Class      92.0   92.0  1500.0  1500.0  1365.0  1365.0
# Audi       A1           99.0   99.0  1600.0  1600.0  1150.0  1150.0
#            A4          104.0  104.0  2000.0  2000.0  1490.0  1490.0
#            A6          114.0  114.0  2000.0  2000.0  1725.0  1725.0
# Opel       Astra        97.0   97.0  1600.0  1600.0  1330.0  1330.0
# Toyoty     Aygo         99.0   99.0  1000.0  1000.0   790.0   790.0
# Ford       B-Max       104.0  104.0  1600.0  1600.0  1235.0  1235.0
# ...

# %%
import pandas as pd
sales = pd.read_excel('../dataset/Superstore Sales.xls',sheet_name=0)
sales.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
sales.isnull().sum()
# Out:
# Row ID                   0
# Order ID                 0
# Order Date               0
# Order Priority           0
# Order Quantity           0
# Sales                    0
# Discount                 0
# Ship Mode                0
# Profit                   0
# Unit Price               0
# Shipping Cost            0
# Customer Name            0
# Province                 0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                8399 non-null   int64
#  1   Order ID              8399 non-null   int64
#  2   Order Date            8399 non-null   datetime64[ns]
#  3   Order Priority        8399 non-null   object
#  4   Order Quantity        8399 non-null   int64
#  5   Sales                 8399 non-null   float64
#  6   Discount              8399 non-null   float64
#  7   Ship Mode             8399 non-null   object
#  8   Profit                8399 non-null   float64
#  9   Unit Price            8399 non-null   float64
#  10  Shipping Cost         8399 non-null   float64
#  11  Customer Name         8399 non-null   object
#  12  Province              8399 non-null   object
#  13  Region                8399 non-null   object
# ...

# %%
sales.describe().round(2).T
# Out:
#                       count                           mean  \
# Row ID               8399.0                         4200.0
# Order ID             8399.0                       29965.18
# Order Date             8399  2010-12-25 00:40:58.578402048
# Order Quantity       8399.0                          25.57
# Sales                8399.0                        1775.88
# Discount             8399.0                           0.05
# Profit               8399.0                         181.18
# Unit Price           8399.0                          89.35
# Shipping Cost        8399.0                          12.84
# Product Base Margin  8336.0                           0.51
# Ship Date              8399  2010-12-27 01:28:48.634361088
#
#                                      min                  25%  \
# Row ID                               1.0               2100.5
# Order ID                             3.0              15011.5
# Order Date           2009-01-01 00:00:00  2009-12-20 00:00:00
# ...

# %%
sales.groupby(by=['Order Priority','Region','Product Category'])[['Sales','Discount','Profit']].aggregate(['mean','median','var','std']).sort_values(by='Order Priority')
# Out:
#                                                 Sales             \
#                                                  mean     median
# Order Priority Region   Product Category
# Critical       Atlantic Furniture         2481.191469   864.1600
#                Yukon    Technology        2352.509278   797.9800
#                         Office Supplies    870.996308   212.2800
#                         Furniture         3512.586667  2305.7500
#                West     Technology        2861.505349  1243.9415
# ...                                               ...        ...
# Not Specified  Atlantic Office Supplies    786.569391   241.1900
#                         Furniture         2722.175902  1485.0600
#                Yukon    Office Supplies    521.493651   267.8500
#                Ontario  Office Supplies    799.746528   234.3700
#                Yukon    Technology        2960.299516  1865.5215
#
# ...

# %% [markdown]
# ## 07/09/2023 - Merging,Joining and concatenating

# %%
df1 = pd.DataFrame({'A' : ['A0','A1','A2','A3'],
                    'B' : ['B0','B1','B2','B3'],
                    'C' : ['C0','C1','C2','C3'],
                    'D' : ['D0','D1','D2','D3']})
df2 = pd.DataFrame({'A' : ['A5','A6','A7','A8'],
                    'B' : ['B5','B6','B7','B8'],
                    'C' : ['C5','C6','C7','C8'],
                    'D' : ['D5','D6','D7','D8']})
df3 = pd.DataFrame({'A' : ['A9','A10','A11','A12'],
                    'B' : ['B9','B10','B11','B12'],
                    'C' : ['C9','C10','C11','C12'],
                    'D' : ['D9','D10','D11','D12']})

# %%
final_df = pd.concat([df1,df2,df3],ignore_index=True)
final_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A5   B5   C5   D5
# 5    A6   B6   C6   D6
# 6    A7   B7   C7   D7
# 7    A8   B8   C8   D8
# 8    A9   B9   C9   D9
# 9   A10  B10  C10  D10
# 10  A11  B11  C11  D11
# 11  A12  B12  C12  D12

# %%
import pandas as pd
kmart_april = pd.read_csv("../dataset/K-Mart-Data/Sales_April_2019.csv")
kmart_august = pd.read_csv("../dataset/K-Mart-Data/Sales_August_2019.csv")
kmart_december = pd.read_csv("../dataset/K-Mart-Data/Sales_December_2019.csv")
kmart_february = pd.read_csv("../dataset/K-Mart-Data/Sales_February_2019.csv")
kmart_january = pd.read_csv("../dataset/K-Mart-Data/Sales_January_2019.csv")
kmart_july = pd.read_csv("../dataset/K-Mart-Data/Sales_July_2019.csv")
kmart_june = pd.read_csv("../dataset/K-Mart-Data/Sales_June_2019.csv")
kmart_march = pd.read_csv("../dataset/K-Mart-Data/Sales_March_2019.csv")
kmart_may = pd.read_csv("../dataset/K-Mart-Data/Sales_May_2019.csv")
kmart_november = pd.read_csv("../dataset/K-Mart-Data/Sales_November_2019.csv")
kmart_october = pd.read_csv("../dataset/K-Mart-Data/Sales_October_2019.csv")
kmart_september = pd.read_csv("../dataset/K-Mart-Data/Sales_September_2019.csv")

# %%
kmart = map(pd.read_csv,["../dataset/K-Mart-Data/Sales_April_2019.csv","./K-Mart-Data/Sales_August_2019.csv","./K-Mart-Data/Sales_December_2019.csv","./K-Mart-Data/Sales_February_2019.csv","./K-Mart-Data/Sales_January_2019.csv","./K-Mart-Data/Sales_July_2019.csv","./K-Mart-Data/Sales_June_2019.csv","./K-Mart-Data/Sales_March_2019.csv","./K-Mart-Data/Sales_May_2019.csv","./K-Mart-Data/Sales_November_2019.csv","./K-Mart-Data/Sales_October_2019.csv","./K-Mart-Data/Sales_September_2019.csv"])
kmart

# %%
kmart_report = pd.concat(kmart)
kmart_report
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1','D2','D3']})

# %%
left.join(right,lsuffix="1",rsuffix="1")
# Out:
#   key1   A   B key1   C   D
# 0   K0  A0  B0   K0  C0  D0
# 1   K1  A1  B1   K1  C1  D1
# 2   K2  A2  B2   K2  C2  D2
# 3   K3  A3  B3   K3  C3  D3

# %%
direction = pd.concat([left,right],axis=1)
direction
# Out:
#   key   A   B key   C   D
# 0  K0  A0  B0  K0  C0  D0
# 1  K1  A1  B1  K1  C1  D1
# 2  K2  A2  B2  K2  C2  D2
# 3  K3  A3  B3  K3  C3  D3

# %%
direction = pd.merge(left,right)
direction
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
employee = pd.DataFrame({'ID' : [1,2,3],
                    'Name' : ["Anita","Anil","Hina"],
                    'Age' : [34,45,56]
                    })
salary = pd.DataFrame({'ID' : [2,4],
                    'Salary' : [34000,55000]
                    })

# %%
pd.merge(employee,salary,how="left")
# Out:
#    ID   Name  Age   Salary
# 0   1  Anita   34      NaN
# 1   2   Anil   45  34000.0
# 2   3   Hina   56      NaN

# %%
employee = pd.DataFrame({'ID' : [1,2,3],
                    'Name' : ["Anita","Anil","Hina"],
                    'Age' : [34,45,56]
                    })
salary = pd.DataFrame({'ID' : [2,4],
                    'Salary' : [34000,55000]
                    })

gender = pd.DataFrame({'ID' : [1,2,3],
                    'Gender' : ["Female","Male","Female"]
                    })

# %% [markdown]
# ### 12/09/2023 - Variable remaining

# %%
import pandas as pd
startups = pd.read_csv("../dataset/50_Startups miss.csv")

# %%
startups_copy = startups.copy()

# %%
startups['R&D Spend1'] = startups['R&D Spend']
startups.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80              NaN    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    R&D Spend1
# 0   165349.20
# 1   162597.70
# 2   153441.51
# 3   144372.41
# 4   142107.34

# %%
startups.drop(columns=['R&D Spend'],inplace=True)

# %%
startups.columns = ['R&D Spend1','Administration', 'Marketing Spend', 'State', 'Profit']
startups.head()
# Out:
#    R&D Spend1  Administration Marketing Spend      State     Profit
# 0   136897.80             NaN        New York  192261.83  165349.20
# 1   151377.59       443898.53      California  191792.06  162597.70
# 2   101145.55       407934.54         Florida  191050.39  153441.51
# 3   118671.85       383199.62        New York  182901.99  144372.41
# 4    91391.77       366168.42         Florida  166187.94  142107.34

# %%
startups = startups_copy.copy()

# %%
startups.columns =['R&D Spend1', 'Administration', 'Marketing Spend', 'State', 'Profit']
startups.head()
# Out:
#    R&D Spend1  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80              NaN    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94

# %%
startups.rename(columns={"Administration" : "Admin"},inplace=True)
startups.head()
# Out:
#    R&D Spend      Admin  Marketing Spend       State     Profit
# 0  165349.20  136897.80              NaN    New York  192261.83
# 1  162597.70  151377.59        443898.53  California  191792.06
# 2  153441.51  101145.55        407934.54     Florida  191050.39
# 3  144372.41  118671.85        383199.62    New York  182901.99
# 4  142107.34   91391.77        366168.42     Florida  166187.94

# %%
startups.rename({"Admin" : "Administration"},axis=1,inplace=True)
startups.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80              NaN    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startups = startups.transpose()
startups.head()
# Out:
#    R&D Spend      Admin Marketing Spend       State     Profit
# 0   165349.2   136897.8             NaN    New York  192261.83
# 1   162597.7  151377.59       443898.53  California  191792.06
# 2  153441.51  101145.55       407934.54     Florida  191050.39
# 3  144372.41  118671.85       383199.62    New York  182901.99
# 4  142107.34   91391.77       366168.42     Florida  166187.94

# %%
startups.rename({"Administration" : "Admin"},axis=0,inplace=True)
startups.head()
# Out:
#                         0           1          2          3          4   \
# R&D Spend         165349.2    162597.7  153441.51  144372.41  142107.34
# Admin             136897.8   151377.59  101145.55  118671.85   91391.77
# Marketing Spend        NaN   443898.53  407934.54  383199.62  366168.42
# State             New York  California    Florida   New York    Florida
# Profit           192261.83   191792.06  191050.39  182901.99  166187.94
#
#                         5           6          7          8           9   ...  \
# R&D Spend         131876.9   134615.46  130298.13  120542.52   123334.88  ...
# Admin             99814.71   147198.87  145530.06  148718.95   108679.17  ...
# Marketing Spend  362861.36   127716.82  323876.68  311613.29   304981.62  ...
# State             New York  California    Florida   New York  California  ...
# Profit           156991.12   156122.51   155752.6  152211.77   149759.96  ...
#
# ...

# %%
startups = startups_copy.copy()

# %%
startups.drop(columns=['State'],index=1,inplace=True)

# %%
startups.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80              NaN  192261.83
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94
# 5  131876.90        99814.71        362861.36  156991.12

# %%
del startups['Profit']

# %%
startups.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80              NaN    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
startups.drop(columns=['R&D Spend','Marketing Spend'],inplace=True)

# %%
startups.head()
# Out:
#    Administration       State
# 0       136897.80    New York
# 1       151377.59  California
# 2       101145.55     Florida
# 3       118671.85    New York
# 4        91391.77     Florida
