# %% [markdown]
# # 08/11/23 - Principal Component Analysis
# Principal Components analysis or PCA is a popular dimensionality reduction technique you can use to avoid "curse of dimensionality".<br>
# The curse of dimensionality occurs when we have too many feature and less data points.<br>
# It is a data preprocessing algo<br>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df = pd.read_csv("../../dataset/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
X = df.drop(columns=['Class'])
X.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
ss = StandardScaler()
new_data = ss.fit_transform(X)
new_data
# Out:
# array([[-1.99658302, -0.69424232, -0.04407492, ...,  0.33089162,
#         -0.06378115,  0.24496426],
#        [-1.99658302,  0.60849633,  0.16117592, ..., -0.02225568,
#          0.04460752, -0.34247454],
#        [-1.99656197, -0.69350046, -0.81157783, ..., -0.13713686,
#         -0.18102083,  1.16068593],
#        ...,
#        [ 1.6419735 ,  0.98002374, -0.18243372, ...,  0.01103672,
#         -0.0804672 , -0.0818393 ],
#        [ 1.6419735 , -0.12275539,  0.32125034, ...,  0.26960398,
#          0.31668678, -0.31324853],
#        [ 1.64205773, -0.27233093, -0.11489898, ..., -0.00598394,
#          0.04134999,  0.51435531]])

# %%
pca = PCA(n_components=3)#components
pcs = pca.fit_transform(X)
pcs
# Out:
# array([[ 9.48138629e+04,  5.59794671e+01,  7.39941871e-01],
#        [ 9.48138546e+04, -9.09536597e+01, -1.43015334e+00],
#        [ 9.48128757e+04,  2.85024840e+02,  2.49508915e-01],
#        ...,
#        [-7.79741415e+04, -1.61186800e+01, -1.41135952e+00],
#        [-7.79741447e+04, -7.39987151e+01,  6.19578190e-01],
#        [-7.79781331e+04,  1.33004366e+02,  6.32008757e-01]])

# %%
principalDF = pd.DataFrame(pcs,columns=['PC1','PC2','PC3'])
principalDF.head()
# Out:
#             PC1         PC2       PC3
# 0  94813.862881   55.979467  0.739942
# 1  94813.854640  -90.953660 -1.430153
# 2  94812.875662  285.024840  0.249509
# 3  94812.861396   29.859853  0.464588
# 4  94811.858408  -23.652028  0.861791

# %%
pca.explained_variance_
# Out:
# array([2.25512401e+09, 6.25548602e+04, 3.70417086e+00])

# %%
pca_model = PCA(n_components=0.9)# variance
pca_model.fit_transform(new_data)
pca_model
# Out:
# PCA(n_components=0.9)

# %%
pca_model.explained_variance_
# Out:
# array([1.95826326, 1.6836999 , 1.00000351, 1.00000351, 1.00000351,
#        1.00000351, 1.00000351, 1.00000351, 1.00000351, 1.00000351,
#        1.00000351, 1.00000351, 1.00000351, 1.00000351, 1.00000351,
#        1.00000351, 1.00000351, 1.00000351, 1.00000351, 1.00000351,
#        1.00000351, 1.00000351, 1.00000351, 1.00000351, 1.00000351,
#        1.00000351])
