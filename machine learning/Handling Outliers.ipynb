# %%
# Use Z-Score Method for Noramlly distributed data
# otherwise use IQR method

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("titanic.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Age column

# %%
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
sns.distplot(data.Age.dropna())
plt.show()
# Out:
# C:\Users\kk\AppData\Local\Temp\ipykernel_13112\2883866815.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.Age.dropna())

# %%
plt.hist(data.Age, bins=50)
plt.show()

# %%
plt.boxplot(data.Age.dropna())
plt.show()

# %%
data.Age.describe().round(2)
# Out:
# count    714.00
# mean      29.70
# std       14.53
# min        0.42
# 25%       20.12
# 50%       28.00
# 75%       38.00
# max       80.00
# Name: Age, dtype: float64

# %% [markdown]
# # Removing Outliers Using Trimming Method

# %% [markdown]
# ## Detecting Outliers using Z-Score

# %%
# Assuming my variable under study is normally distributed

upp_fence = data.Age.mean() + 3 * data.Age.std()
low_fence = data.Age.mean() - 3 * data.Age.std()

print("Lower Fence: ", low_fence)
print("upper Fence: ", upp_fence)
# Out:
# Lower Fence:  -13.88037434994331
# upper Fence:  73.27860964406095

# %%
# Locating values above 73 

data[data.Age>=73]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 630  male  80.0      0      0   27042  30.000   A23        S
# 851  male  74.0      0      0  347060   7.775   NaN        S

# %%
data.loc[data['Age']>=73]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 630  male  80.0      0      0   27042  30.000   A23        S
# 851  male  74.0      0      0  347060   7.775   NaN        S

# %%
data1 = data.loc[~(data['Age']>=73)]
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Repeat this on Fare column in the same datset
# Practice Now
# Send me a boxplot before removing outliers and 
# after removing outliers

# %% [markdown]
# ## Detecting Outliers using IQR

# %%
# Criteria : data points that lie 1.5*IQR above Q3 and below Q1

# %%
Q1 = data.Age.quantile(0.25)
Q3 = data.Age.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 17.875

# %%
upp_bound = Q3 + 1.5*IQR
low_bound = Q1 - 1.5*IQR
print("Upper Bound: ",upp_bound)
print("lower Bound: ", low_bound)
# Out:
# Upper Bound:  64.8125
# lower Bound:  -6.6875

# %%
data.loc[data['Age']>=65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 280          281         0       3                      Duane, Mr. Frank
# 456          457         0       1             Millet, Mr. Francis Davis
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Removing Outliers Using Capping Method

# %%
data.Age = np.where(data.Age>= upp_bound,
         upp_bound,
         data.Age)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.Age.describe().round(2)
# Out:
# count    714.00
# mean      29.62
# std       14.32
# min        0.42
# 25%       20.12
# 50%       28.00
# 75%       38.00
# max       64.81
# Name: Age, dtype: float64

# %%
## For both 

data.Age = np.where(data.Age>= upp_bound,
         upp_bound,
                    np.where(data.Age>= low_bound_bound,
                            low_bound,
                             data.Age))
data
